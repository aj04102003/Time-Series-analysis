# %%
import numpy as np # linear algebra
import pandas as pd

# %%
import pandas as pd
import numpy as np
import datetime as dt
import os
import warnings
from collections import UserDict
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image
# %matplotlib inline
import matplotlib.dates as mpl_dates
import seaborn as sns
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
from statsmodels.tsa.api import acf, pacf, graphics
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
import math
from keras.models import Model, Sequential
from keras.layers import GRU, Dense
from keras.callbacks import EarlyStopping

# %%
import plotly.graph_objects as go

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ADANIPORTS = pd.read_csv ('/content/drive/MyDrive/MINI Project/ADANIPORTS (1).csv')
ADANIPORTS.head (10000)
# Out:
#             Date      Symbol Series  Prev Close    Open     High     Low  \
# 0     2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1     2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2     2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3     2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4     2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...          ...         ...    ...         ...     ...      ...     ...
# 3317  2021-04-26  ADANIPORTS     EQ      725.35  733.00   739.65  728.90
# 3318  2021-04-27  ADANIPORTS     EQ      730.75  735.00   757.50  727.35
# 3319  2021-04-28  ADANIPORTS     EQ      749.15  755.00   760.00  741.10
# 3320  2021-04-29  ADANIPORTS     EQ      746.25  753.20   765.85  743.40
# 3321  2021-04-30  ADANIPORTS     EQ      746.75  739.00   759.45  724.50
#
#        Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
TSLA= pd.read_csv ('/content/drive/MyDrive/MINI Project/TSLA (1).csv')
TSLA.head (10000)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     2010-06-30   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     2010-07-01   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     2010-07-02   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     2010-07-06   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2411  2020-01-28  568.489990  576.809998  558.080017  566.900024  566.900024
# 2412  2020-01-29  575.690002  589.799988  567.429993  580.989990  580.989990
# 2413  2020-01-30  632.419983  650.880005  618.000000  640.809998  640.809998
# 2414  2020-01-31  640.000000  653.000000  632.520020  650.570007  650.570007
# 2415  2020-02-03  673.690002  786.140015  673.520020  780.000000  780.000000
#
#         Volume
# 0     18766300
# ...

# %%
from datetime import datetime

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cc4f75e9-8f55-4190-8957-4acea1cea655" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc4f75e9-8f55-4190-8957-4acea1cea655">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('ADANIPORTS (1).csv')[-200:]
df
df.set_index(pd.DatetimeIndex(df['Date'].values))
# Out:
#                   Date      Symbol Series  Prev Close    Open    High     Low  \
# 2020-07-14  2020-07-14  ADANIPORTS     EQ      332.20  332.70  333.50  319.70
# 2020-07-15  2020-07-15  ADANIPORTS     EQ      320.40  320.55  324.50  312.90
# 2020-07-16  2020-07-16  ADANIPORTS     EQ      315.15  317.00  317.45  309.60
# 2020-07-17  2020-07-17  ADANIPORTS     EQ      311.20  312.00  318.90  310.60
# 2020-07-20  2020-07-20  ADANIPORTS     EQ      313.00  316.00  318.70  310.35
# ...                ...         ...    ...         ...     ...     ...     ...
# 2021-04-26  2021-04-26  ADANIPORTS     EQ      725.35  733.00  739.65  728.90
# 2021-04-27  2021-04-27  ADANIPORTS     EQ      730.75  735.00  757.50  727.35
# 2021-04-28  2021-04-28  ADANIPORTS     EQ      749.15  755.00  760.00  741.10
# 2021-04-29  2021-04-29  ADANIPORTS     EQ      746.25  753.20  765.85  743.40
# 2021-04-30  2021-04-30  ADANIPORTS     EQ      746.75  739.00  759.45  724.50
#
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],open=df['Open'],high=df['High'],low=df['Low'],close=df['Close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from datetime import datetime

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c4f36dc2-1a4e-47e2-9563-34397908014a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4f36dc2-1a4e-47e2-9563-34397908014a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('TSLA (1).csv')[-200:]
df
df.set_index(pd.DatetimeIndex(df['Date'].values))
# Out:
#                   Date        Open        High         Low       Close  \
# 2019-04-18  2019-04-18  271.230011  274.839996  269.750000  273.260010
# 2019-04-22  2019-04-22  269.000000  269.679993  262.480011  262.750000
# 2019-04-23  2019-04-23  260.149994  265.600006  255.750000  263.899994
# 2019-04-24  2019-04-24  263.850006  265.320007  258.000000  258.660004
# 2019-04-25  2019-04-25  255.000000  259.000000  246.070007  247.630005
# ...                ...         ...         ...         ...         ...
# 2020-01-28  2020-01-28  568.489990  576.809998  558.080017  566.900024
# 2020-01-29  2020-01-29  575.690002  589.799988  567.429993  580.989990
# 2020-01-30  2020-01-30  632.419983  650.880005  618.000000  640.809998
# 2020-01-31  2020-01-31  640.000000  653.000000  632.520020  650.570007
# 2020-02-03  2020-02-03  673.690002  786.140015  673.520020  780.000000
#
#              Adj Close    Volume
# 2019-04-18  273.260010   5876300
# 2019-04-22  262.750000  12147100
# ...

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],open=df['Open'],high=df['High'],low=df['Low'],close=df['Close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import statsmodels.api as sm
def seasonal_decompose (y):
    decomposition = sm.tsa.seasonal_decompose(y, model='additive',extrapolate_trend='freq')
    fig = decomposition.plot()
    fig.set_size_inches(14,7)
    plt.show()
    seasonal_decompose(y)

# %%
def test_stationarity(timeseries, title):

    #Determing rolling statistics
    rolmean = pd.Series(timeseries).rolling(window=12).mean()
    rolstd = pd.Series(timeseries).rolling(window=12).std()

    fig, ax = plt.subplots(figsize=(16, 4))
    ax.plot(timeseries, label= title)
    ax.plot(rolmean, label='rolling mean');
    ax.plot(rolstd, label='rolling std (x10)');
    ax.legend()

# %%
pd.options.display.float_format = '{:.8f}'.format

test_stationarity(seasonal_decompose(y),'raw data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a9436eedffdf> in <cell line: 3>()
#       1 pd.options.display.float_format = '{:.8f}'.format
#       2
# ----> 3 test_stationarity(seasonal_decompose(y),'raw data')
#
# NameError: name 'y' is not defined

# %%
from statsmodels.tsa.stattools import adfuller

def ADF_test(timeseries, dataDesc):
    print(' > Is the {} stationary ?'.format(dataDesc))
    dftest = adfuller(timeseries.dropna(), autolag='AIC')
    print('Test statistic = {:.3f}'.format(dftest[0]))
    print('P-value = {:.3f}'.format(dftest[1]))
    print('Critical values :')
    for k, v in dftest[4].items():
        print('\t{}: {} - The data is {} stationary with {}% confidence'.format(k, v, 'not' if v<dftest[0] else '', 100-int(k[:-1])))

# %%
ADF_test(y,'raw data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-35731f3a2222> in <cell line: 1>()
# ----> 1 ADF_test(y,'raw data')
#
# NameError: name 'y' is not defined

# %%
y_detrend =  (y - y.rolling(window=12).mean())/y.rolling(window=12).std()

test_stationarity(y_detrend,'de-trended data')
ADF_test(y_detrend,'de-trended data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-724cc7d101ba> in <cell line: 1>()
# ----> 1 y_detrend =  (y - y.rolling(window=12).mean())/y.rolling(window=12).std()
#       2
#       3 test_stationarity(y_detrend,'de-trended data')
#       4 ADF_test(y_detrend,'de-trended data')
#
# NameError: name 'y' is not defined

# %%
y_12lag =  y - y.shift(12)

test_stationarity(y_12lag,'12 lag differenced data')
ADF_test(y_12lag,'12 lag differenced data')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-56c016930cc0> in <cell line: 1>()
# ----> 1 y_12lag =  y - y.shift(12)
#       2
#       3 test_stationarity(y_12lag,'12 lag differenced data')
#       4 ADF_test(y_12lag,'12 lag differenced data')
#
# NameError: name 'y' is not defined

# %%
TSLA= pd.read_csv ('/content/drive/MyDrive/MINI Project/TSLA (1).csv')
TSLA.head (10000)
# Out:
#             Date         Open         High          Low        Close  \
# 0     2010-06-29  19.00000000  25.00000000  17.54000100  23.88999900
# 1     2010-06-30  25.79000100  30.42000000  23.29999900  23.83000000
# 2     2010-07-01  25.00000000  25.92000000  20.27000000  21.95999900
# 3     2010-07-02  23.00000000  23.10000000  18.70999900  19.20000100
# 4     2010-07-06  20.00000000  20.00000000  15.83000000  16.11000100
# ...          ...          ...          ...          ...          ...
# 2411  2020-01-28 568.48999000 576.80999800 558.08001700 566.90002400
# 2412  2020-01-29 575.69000200 589.79998800 567.42999300 580.98999000
# 2413  2020-01-30 632.41998300 650.88000500 618.00000000 640.80999800
# 2414  2020-01-31 640.00000000 653.00000000 632.52002000 650.57000700
# 2415  2020-02-03 673.69000200 786.14001500 673.52002000 780.00000000
#
#         Adj Close    Volume
# 0     23.88999900  18766300
# 1     23.83000000  17187100
# 2     21.95999900   8218800
# ...

# %%
TSLA_to_train =TSLA[:'2015-11-27'] # dataset to train
TSLA_to_val = TSLA['2016-04-26':] # last X months for test
predict_date = len(TSLA) - len(TSLA[:'2023-09-03']) # the number of data points for the test set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a4285ec06e31> in <cell line: 1>()
# ----> 1 TSLA_to_train =TSLA[:'2015-11-27'] # dataset to train
#       2 TSLA_to_val = TSLA['2016-04-26':] # last X months for test
#       3 predict_date = len(TSLA) - len(TSLA[:'2023-09-03']) # the number of data points for the test set
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3777                 return self._getitem_multilevel(key)
#    3778         # Do we have a slicer (on rows)?
# -> 3779         indexer = convert_to_index_sliceable(self, key)
#    3780         if indexer is not None:
#    3781             if isinstance(indexer, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    2492     idx = obj.index
#    2493     if isinstance(key, slice):
# ...
